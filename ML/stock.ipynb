# %%
import seaborn as sns
from matplotlib import pyplot
import numpy as np
import pandas as pd

# %%
csv_path = './code/dataset/all_stocks_5yr.csv'
df = pd.read_csv(csv_path, index_col="date")
df.head()
# Out:
#              open   high    low  close    volume Name
# date
# 2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 619040 entries, 2013-02-08 to 2018-02-07
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   open    619029 non-null  float64
#  1   high    619032 non-null  float64
#  2   low     619032 non-null  float64
#  3   close   619040 non-null  float64
#  4   volume  619040 non-null  int64
#  5   Name    619040 non-null  object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 28.3+ MB

# %%
df.isna().sum() / len(df)
# Out:
# open      0.000018
# high      0.000013
# low       0.000013
# close     0.000000
# volume    0.000000
# Name      0.000000
# dtype: float64

# %%
df['open'] = df['open'].fillna(df['open'].mean())

# %%
df['high'] = df['high'].fillna(df['high'].mean())
df['low'] = df['low'].fillna(df['low'].mean())

# %%
df.isna().sum() / len(df)
# Out:
# open      0.0
# high      0.0
# low       0.0
# close     0.0
# volume    0.0
# Name      0.0
# dtype: float64

# %%
import seaborn as sns
pyplot.figure(figsize=(16, 8))
sns.barplot(data=df)
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
pyplot.figure(figsize=(12,9))
sns.lineplot(data=df)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df.drop('Name', axis = 1, inplace=True)
df.sample(5)
# Out:
#               open     high     low   close   volume
# date
# 2013-03-08   73.86   74.170   73.63   73.99   293656
# 2016-11-03   83.49   84.930   79.72   79.95  5048660
# 2016-12-30  172.46  172.904  170.72  171.27   214240
# 2017-08-28  247.58  248.390  246.95  247.12   230042
# 2016-06-20   88.71   90.240   88.44   89.13   687544

# %%
df.isna.sum() / len(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b275f5fd507c> in <module>
# ----> 1 df.isna.sum() / len(df)
#
# NameError: name 'df' is not defined

# %%
pyplot.figure(figsize=(10,7))
sns.heatmap(data=corr)
# Out:
# <AxesSubplot:>

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# open           54.150
# high           54.560
# low            53.710
# close          54.165
# volume    3214188.750
# dtype: float64
